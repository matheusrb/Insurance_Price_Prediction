# %%
# !pip install kaggle

# %%
import pandas as pd
from kaggle.api.kaggle_api_extended import KaggleApi
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-55dba4c0dc14> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 from kaggle.api.kaggle_api_extended import KaggleApi
#
# /usr/local/lib/python3.10/dist-packages/kaggle/__init__.py in <module>
#       5
#       6 api = KaggleApi(ApiClient())
# ----> 7 api.authenticate()
#
# /usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py in authenticate(self)
#     396                 return
#     397             else:
# --> 398                 raise IOError('Could not find {}. Make sure it\'s located in'
#     399                               ' {}. Or use the environment method.'.format(
#     400                                   self.config_file, self.config_dir))
#
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
kaggle datasets download -d annetxu/health-insurance-cost-prediction
# Out:
#   File "<ipython-input-3-d63850b49ad9>", line 1
#     kaggle datasets download -d annetxu/health-insurance-cost-prediction
#            ^
# SyntaxError: invalid syntax
